# %% [markdown]
# ## Common Imports in Bneign Packages

# %%
from runpy import run_path

SCRIPT_PATH = (
    r"D:/12. RQ2 eDySec/Adversarial Attacks"
    r"\benign_analyze_common_imports.py"
)

analyzer = run_path(
    SCRIPT_PATH,
    run_name="setup_import_analyzer_library"
)

print("run_analysis available:", "run_analysis" in analyzer)
# Out:
# run_analysis available: True

# %%
INPUT_FOLDER = (
    r"D:\10. RQ1 DySec\Step 9 DownloadSelectedBenignPackages"
    r"\Benign_Packages"
)

OUTPUT_FOLDER = (
    r"D:/12. RQ2 eDySec/Adversarial Attacks"
    r"\benign_analyze_common_imports_results"
)

results = analyzer["run_analysis"](
    input_folder=INPUT_FOLDER,
    output_folder=OUTPUT_FOLDER,
    top_k=20,
    max_setup_mb=5
)
# Out:
# Input folder : D:\10. RQ1 DySec\Step 9 DownloadSelectedBenignPackages\Benign_Packages
# Output folder: D:\12. RQ2 eDySec\Adversarial Attacks\benign_analyze_common_imports_results
# Scanning archives without extracting them...
#
# Checked 500/6,725 files...
# Checked 1,000/6,725 files...
# Checked 1,500/6,725 files...
# Checked 2,000/6,725 files...
# Checked 2,500/6,725 files...
# Checked 3,000/6,725 files...
# Checked 3,500/6,725 files...
# Checked 4,000/6,725 files...
# Checked 4,500/6,725 files...
# Checked 5,000/6,725 files...
# Checked 5,500/6,725 files...
# Checked 6,000/6,725 files...
# Checked 6,500/6,725 files...
# Excel workbook: D:\12. RQ2 eDySec\Adversarial Attacks\benign_analyze_common_imports_results\setup_import_analysis.xlsx
#
# Analysis summary
#                                           metric  value
#                        Files visited recursively   6725
#                       Supported ZIP/TAR archives   6725
# ...
