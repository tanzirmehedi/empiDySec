# %% [markdown]
# **Feature Selection Method:** ANOVA
# **Dataset:** QUT-DV25 (Combined)
# **Developed By:** eDySec Research Team
# **Plartform:** Ubuntu
#
# All experiments in this notebook were conducted using **Python 3.10** with the following libraries:
#
# `pandas==1.5.3`,
# `scikit-learn==1.2.2`,
# `openpyxl`,
# `numpy==1.23.5`,
# `scipy==1.9.3`,
# `tensorflow==2.11.0`,
# `matplotlib==3.7.1`,
# `seaborn==0.12.2`,
# `joblib==1.3.2`,
# `shap==0.41.0`,
# `lime`,
# `flaml[automl]==2.5.0`,
# `notebook==6.5.6`,
# `pywinpty==2.0.10`  (Only for windows)  `threadpoolctl==3.1.0` (for Ubuntu)
# `terminado==0.17.1`,
# `transformers==4.49.0`.
#
# #### Full Environment Setup: https://github.com/tanzirmehedi/eDySec
#
# These versions were used to ensure **consistent and reproducible experimental results**.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import hstack
from scipy.sparse import csr_matrix
from sklearn.metrics import (
    accuracy_score, confusion_matrix, roc_auc_score, roc_curve,
    precision_recall_fscore_support, cohen_kappa_score
)
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import time
import joblib
import gc
from sklearn.feature_selection import f_classif

# %%
# This will allow TensorFlow to allocate as much GPU memory as needed, including full 16GB if needed.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Disable memory growth (optional - default is False)
        tf.config.experimental.set_memory_growth(gpus[0], False)
        print("Memory growth disabled (default behavior).")
    except RuntimeError as e:
        print("Error:", e)
# Out:
# Memory growth disabled (default behavior).

# %%
file_path = 'QUT-DV25_'+DATASET_NAME+'_Traces.csv'
data = pd.read_csv(file_path)

# %%
gc.collect()
tf.keras.backend.clear_session()

# %%
data.head()
# Out:
#               Package_Name IO_Operations File_Operations Network_Operations  \
# 0  10Cent10-999.0.4.tar.gz         ioctl             NaN   getrandom, uname
# 1  10Cent11-999.0.4.tar.gz   ioctl, poll             NaN              uname
# 2    11Cent-999.0.0.tar.gz   ioctl, poll           pipe2   getrandom, uname
# 3    11Cent-999.0.1.tar.gz   ioctl, poll             NaN              uname
# 4    11Cent-999.0.2.tar.gz   poll, ioctl             NaN              uname
#
#   Time_Operations Security_Operations    Process_Operations  \
# 0             NaN                 NaN                getpid
# 1             NaN                 NaN         wait4, getpid
# 2             NaN                 NaN  vfork, wait4, getpid
# 3             NaN                 NaN                getpid
# 4             NaN                 NaN                getpid
#
#                                       Read_Processes  \
# 0  opensnoop-bpfcc, filetop-bpfcc, tcpstates-bpfc...
# 1  opensnoop-bpfcc, filetop-bpfcc, tcpstates-bpfc...
# 2  opensnoop-bpfcc, filetop-bpfcc, tcpstates-bpfc...
# 3  opensnoop-bpfcc, filetop-bpfcc, tcpstates-bpfc...
# 4  opensnoop-bpfcc, filetop-bpfcc, tcpstates-bpfc...
#
#                                      Write_Processes  \
# 0  opensnoop-bpfcc, strace, StreamTrans, Classif~...
# 1  opensnoop-bpfcc, strace, StreamTrans, Classif~...
# 2  opensnoop-bpfcc, strace, StreamTrans, Classif~...
# 3  opensnoop-bpfcc, strace, StreamTrans, Classif~...
# 4  opensnoop-bpfcc, strace, StreamTrans, Classif~...
#
#                                   Read_Data_Transfer  ...  \
# 0  opensnoop-bpfcc, filetop-bpfcc, pip, gnome-sys...  ...
# 1  opensnoop-bpfcc, filetop-bpfcc, pip, gnome-sys...  ...
# 2  opensnoop-bpfcc, filetop-bpfcc, pip, gnome-sys...  ...
# 3  opensnoop-bpfcc, filetop-bpfcc, pip, gnome-sys...  ...
# 4  opensnoop-bpfcc, filetop-bpfcc, pip, gnome-sys...  ...
#
#                             Pattern_2                      Pattern_3  \
# 0             fstat -> ioctl -> lseek       openat -> fstat -> ioctl
# 1                read -> read -> read  newfstatat -> openat -> fstat
# 2  newfstatat -> newfstatat -> openat           read -> read -> read
# 3                read -> read -> read  newfstatat -> openat -> fstat
# 4                read -> read -> read  newfstatat -> openat -> fstat
#
#                             Pattern_4                           Pattern_5  \
# 0  newfstatat -> newfstatat -> openat       newfstatat -> openat -> fstat
# 1             ioctl -> ioctl -> ioctl  newfstatat -> newfstatat -> openat
# 2       newfstatat -> openat -> fstat             fstat -> ioctl -> lseek
# 3            openat -> fstat -> fcntl             fstat -> fcntl -> fstat
# 4                read -> poll -> read                poll -> read -> read
#
#                                            Pattern_6  \
# 0  newfstatat -> newfstatat -> newfstatat -> no-e...
# 1  newfstatat -> newfstatat -> newfstatat -> no-e...
# 2  newfstatat -> newfstatat -> newfstatat -> no-e...
# 3  newfstatat -> newfstatat -> newfstatat -> no-e...
# 4  newfstatat -> newfstatat -> newfstatat -> no-e...
#
#                                            Pattern_7  \
# 0       fstat -> ioctl -> lseek -> no-error -> no-fd
# 1          read -> read -> read -> no-error -> no-fd
# 2  newfstatat -> newfstatat -> openat -> no-error...
# 3          read -> read -> read -> no-error -> no-fd
# 4          read -> read -> read -> no-error -> no-fd
#
#                                            Pattern_8  \
# 0      openat -> fstat -> ioctl -> no-error -> no-fd
# 1  newfstatat -> openat -> fstat -> no-error -> n...
# 2          read -> read -> read -> no-error -> no-fd
# 3  newfstatat -> openat -> fstat -> no-error -> n...
# 4  newfstatat -> openat -> fstat -> no-error -> n...
#
#                                           Pattern_9  \
# 0  ioctl -> lseek -> lseek -> error=ENOTTY -> no-fd
# 1      ioctl -> ioctl -> ioctl -> no-error -> no-fd
# 2     openat -> fstat -> ioctl -> no-error -> no-fd
# 3     openat -> fstat -> fcntl -> no-error -> no-fd
# 4     read -> poll -> read -> error=EAGAIN -> no-fd
#
#                                           Pattern_10  Level
# 0         read -> read -> close -> no-error -> no-fd      1
# 1       fcntl -> fstat -> fcntl -> no-error -> no-fd      1
# 2  newfstatat -> openat -> fstat -> no-error -> n...      1
# 3       fstat -> fcntl -> fstat -> no-error -> no-fd      1
# 4  newfstatat -> newfstatat -> openat -> no-error...      1
#
# [5 rows x 41 columns]

# %%
# Separate target
X = data.drop(columns=['Level'])
y = data['Level']

if y.dtype == 'object' or y.dtype.name == 'category':
    y = LabelEncoder().fit_transform(y)

# Separate numerical and categorical features
numerical_cols = X.select_dtypes(include=['int64','float64']).columns.tolist()
categorical_cols = X.select_dtypes(include=['object','category']).columns.tolist()

X_num = X[numerical_cols]

# Encode categorical features as numeric codes
X_cat = X[categorical_cols].apply(lambda col: LabelEncoder().fit_transform(col.astype(str)))

# Combine numerical + encoded categorical features
X_encoded = pd.concat([X_num, X_cat], axis=1)

# Compute ANOVA F-scores
f_scores, _ = f_classif(X_encoded, y)

feature_df = pd.DataFrame({
    'feature': X_encoded.columns,
    'f_score': f_scores
})

# Select top 30% features by F-score
threshold = np.percentile(f_scores, 70)  # top 30%
feature_df['status'] = np.where(feature_df['f_score'] >= threshold, 'selected', 'deleted')

selected_features = feature_df[feature_df['status']=='selected']
deleted_features = feature_df[feature_df['status']=='deleted']

print("Selected features (name + F-score):\n", selected_features)
print("\nDeleted features (name + F-score):\n", deleted_features)
# Out:
# Selected features (name + F-score):
#                       feature       f_score    status
# 0            Root_DIR_Access   1356.632191  selected
# 2            Home_DIR_Access   3717.820308  selected
# 3            User_DIR_Access   1925.052180  selected
# 6           Other_DIR_Access   1455.291634  selected
# 15             IO_Operations  41102.376740  selected
# 16           File_Operations   3770.685164  selected
# 17        Network_Operations   2577.048491  selected
# 21            Read_Processes   1495.945982  selected
# 22           Write_Processes   6790.987920  selected
# 24       Write_Data_Transfer   2016.757758  selected
# 25     File_Access_Processes   1311.714160  selected
# 27  Direct_Dependencies_List   1214.012264  selected
#
# Deleted features (name + F-score):
#                         feature      f_score   status
# 1              Temp_DIR_Access    67.277257  deleted
# 4               Sys_DIR_Access     5.008980  deleted
# 5               Etc_DIR_Access   831.338406  deleted
# 7             Local_IPs_Access    85.724500  deleted
# 8            Remote_IPs_Access   488.592645  deleted
# 9            Local_Port_Access   431.261407  deleted
# 10          Remote_Port_Access  1002.227790  deleted
# 11          Total_Dependencies     0.233547  deleted
# 12         Direct_Dependencies     1.335741  deleted
# 13       Indirect_Dependencies     1.557905  deleted
# 14                Package_Name    22.678863  deleted
# 18             Time_Operations  1104.647253  deleted
# 19         Security_Operations     1.815865  deleted
# 20          Process_Operations   812.949426  deleted
# 23          Read_Data_Transfer  1049.503161  deleted
# 26     Total_Dependencies_List   846.496989  deleted
# 28  Indirect_Dependencies_List   699.501629  deleted
# 29            State_Transition    53.817269  deleted
# 30                   Pattern_1   305.022198  deleted
# 31                   Pattern_2   196.023942  deleted
# 32                   Pattern_3   237.473896  deleted
# 33                   Pattern_4   151.932094  deleted
# 34                   Pattern_5    76.623441  deleted
# 35                   Pattern_6   282.420745  deleted
# 36                   Pattern_7   304.593262  deleted
# 37                   Pattern_8    35.980271  deleted
# 38                   Pattern_9     6.057421  deleted
# 39                  Pattern_10    15.308793  deleted
